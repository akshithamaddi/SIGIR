# %% [markdown]
# <a href="https://colab.research.google.com/github/akshithamaddi/SIGIR/blob/main/Descriptive_Analysis_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df=pd.read_csv("/content/Article_information.csv",encoding="ISO-8859-1")
df
# Out:
#       Unnamed: 0  ... Influentialcitationcount
# 0              0  ...                        0
# 1              1  ...                        0
# 2              2  ...                        0
# 3              3  ...                        0
# 4              4  ...                        0
# ...          ...  ...                      ...
# 4428         762  ...                        0
# 4429         763  ...                        0
# 4430         764  ...                        0
# 4431         765  ...                        0
# 4432         766  ...                        0
#
# [4433 rows x 13 columns]

# %%
#average number of SIGIR Articles per year
df.loc[df['Venue'].str.contains('SIGIR',na=False), 'Venue'] = 'SIGIR'
df1 = df.loc[df['Venue'] == 'SIGIR']
authors_per_year = pd.DataFrame(df1['Year'].value_counts()).reset_index()
authors_per_year.columns = ['Year', 'No.of.Articles']
sort_by_year = authors_per_year.sort_values('Year')
sort_by_year.to_csv("Averagearticlesperyear.csv")

# %%
# Using plotly.express
import plotly.express as px

import pandas as pd
fig = px.line(sort_by_year, x='Year', y='No.of.Articles',title="SIGIR Publications each Year")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="900649f1-6976-4416-82fc-f70b1c9232ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("900649f1-6976-4416-82fc-f70b1c9232ae")) {
#                     Plotly.newPlot(
#                         '900649f1-6976-4416-82fc-f70b1c9232ae',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Year=%{x}<br>No.of.Articles=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": [1971, 1978, 1979, 1981, 1983, 1985, 1986, 1987, 1988, 1989, 1991, 1992, 1993, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [19, 12, 14, 21, 29, 31, 35, 34, 45, 54, 35, 33, 42, 41, 64, 39, 75, 79, 75, 86, 106, 104, 139, 135, 149, 216, 205, 198, 212, 236, 223, 210, 228, 203, 229, 253, 250, 261], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %%
N = 5
sort_by_year["No.of.Articles"].groupby(sort_by_year["No.of.Articles"].index // N).mean()
# Out:
# 0    245.8
# 1    217.8
# 2    178.8
# 3    102.0
# 4     62.6
# 5     38.4
# 6     29.6
# 7     15.0
# Name: No.of.Articles, dtype: float64

# %%
# Import pandas library 
import pandas as pd 
# initialize list of lists 
data = [['2015-2019', 245.8], ['2010-2014', 217.8], ['2005-2009',  178.8],['2000-2004',102.0],['1995-1999',62.6],['1988-1993',38.4],
        ['1981-1987',29.6],['1971-1979',15.0]] 
# Create the pandas DataFrame 
df = pd.DataFrame(data, columns = ['year', 'Average']) 
# print dataframe. 
df
# Out:
#         year  Average
# 0  2015-2019    245.8
# 1  2010-2014    217.8
# 2  2005-2009    178.8
# 3  2000-2004    102.0
# 4  1995-1999     62.6
# 5  1988-1993     38.4
# 6  1981-1987     29.6
# 7  1971-1979     15.0

# %%
#Top Authors ranked by citation count
topauthors = pd.read_csv("Citation_Information.csv")
topauthors.head(5)
# Out:
#    Unnamed: 0             article_id     authorid  ...    year intent isInfluential
# 0           0  10.1145/511285.511288   35022826.0  ...  1975.0    NaN         False
# 1           1  10.1145/511285.511288   40005703.0  ...  1973.0    NaN         False
# 2           2  10.1145/511285.511288  144226072.0  ...  1973.0    NaN         False
# 3           3  10.1145/511285.511288    1777876.0  ...  1977.0    NaN         False
# 4           4  10.1145/511285.511288   48264726.0  ...  1978.0    NaN         False
#
# [5 rows x 12 columns]

# %%
#Auhor analysis and ranking the author based on the total number of articles written.
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("Author_information.csv")
df['authorId'] = df['authorId'].fillna(0).astype(int)
df['count'] = df.groupby('name')['name'].transform('count')
df.drop_duplicates('name', inplace=True)
#df.nlargest(5, ['count'])[["name","authorId","count"]]
df1 = df.sort_values('count',ascending=False)
df1["Rank"] = df1["count"].rank(ascending=0)
df1 = df1.dropna(subset=['Rank'])
header = ["name", "authorId", "Rank"]
df1.to_csv('author_distribution.csv', columns = header)
plotgraph = pd.read_csv("author_distribution.csv")
plotgraph = df.nlargest(20, ['count'])[["name","count"]]
rank=pd.read_csv("author_distribution.csv")
top10rank = rank.head(20)
plotgraph['Rank'] = top10rank['Rank'].values
plotgraph
# Out:
#                       name  count  Rank
# 49          W. Bruce Croft    101   1.0
# 2421      Maarten de Rijke     79   2.0
# 1442         Ryen W. White     57   3.0
# 1333       ChengXiang Zhai     52   4.0
# 2363        Leif Azzopardi     50   5.0
# 1171            Iadh Ounis     48   6.0
# 562            James Allan     47   7.5
# 630        James P. Callan     47   7.5
# 3663       Craig MacDonald     45   9.0
# 2596          Oren Kurland     40  10.0
# 950         Joemon M. Jose     38  11.5
# 1072        Mark Sanderson     38  11.5
# 1177  Charles L. A. Clarke     36  13.5
# 1729                Luo Si     36  13.5
# 1147         Tetsuya Sakai     35  15.0
# 447        Alistair Moffat     33  17.0
# 2228         Tat-Seng Chua     33  17.0
# 3138      Eugene Agichtein     33  17.0
# 438        Susan T. Dumais     32  19.0
# 1175     Gordon V. Cormack     30  21.0

# %%
import plotly.express as px
fig = px.scatter(plotgraph, x="Rank", y="count",
	         size="count", color="name",
                 log_x=True, size_max=60)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="57e96ed7-07e7-441a-a877-1c1e43abbc73" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("57e96ed7-07e7-441a-a877-1c1e43abbc73")) {
#                     Plotly.newPlot(
#                         '57e96ed7-07e7-441a-a877-1c1e43abbc73',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "name=W. Bruce Croft<br>Rank=%{x}<br>count=%{marker.size}", "legendgroup": "name=W. Bruce Croft", "marker": {"color": "#636efa", "size": [101], "sizemode": "area", "sizeref": 0.028055555555555556, "symbol": "circle"}, "mode": "markers", "name": "name=W. Bruce Croft", "showlegend": true, "type": "scatter", "x": [1.0], "xaxis": "x", "y": [101], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=Maarten de Rijke<br>Rank=%{x}<br>count=%{marker.size}", "legendgroup": "name=Maarten de Rijke", "marker": {"color": "#EF553B", "size": [79], "sizemode": "area", "sizeref": 0.028055555555555556, "symbol": "circle"}, "mode": "markers", "name": "name=Maarten de Rijke", "showlegend": true, "type": "scatter", "x": [2.0], "xaxis": "x", "y": [79], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=Ryen W. White<br>Rank=%{x}<br>count=%{marker.size}", "legendgroup": "name=Ryen W. White", "marker": {"color": "#00cc96", "size": [57], "sizemode": "area", "sizeref": 0.028055555555555556, "symbol": "circle"}, "mode": "markers", "name": "name=Ryen W. White", "showlegend": true, "type": "scatter", "x": [3.0], "xaxis": "x", "y": [57], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=ChengXiang Zhai<br>Rank=%{x}<br>count=%{marker.size}", "legendgroup": "name=ChengXiang Zhai", "marker": {"color": "#ab63fa", "size": [52], "sizemode": "area", "sizeref": 0.028055555555555556, "symbol": "circle"}, "mode": "markers", "name": "name=ChengXiang Zhai", "showlegend": true, "type": "scatter", "x": [4.0], "xaxis": "x", "y": [52], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=Leif Azzopardi<br>Rank=%{x}<br>count=%{marker.size}", "legendgroup": "name=Leif Azzopardi", "marker": {"color": "#FFA15A", "size": [50], "sizemode": "area", "sizeref": 0.028055555555555556, "symbol": "circle"}, "mode": "markers", "name": "name=Leif Azzopardi", "showlegend": true, "type": "scatter", "x": [5.0], "xaxis": "x", "y": [50], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=Iadh Ounis<br>Rank=%{x}<br>count=%{marker.size}", "legendgroup": "name=Iadh Ounis", "marker": {"color": "#19d3f3", "size": [48], "sizemode": "area", "sizeref": 0.028055555555555556, "symbol": "circle"}, "mode": "markers", "name": "name=Iadh Ounis", "showlegend": true, "type": "scatter", "x": [6.0], "xaxis": "x", "y": [48], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=James Allan<br>Rank=%{x}<br>count=%{marker.size}", "legendgroup": "name=James Allan", "marker": {"color": "#FF6692", "size": [47], "sizemode": "area", "sizeref": 0.028055555555555556, "symbol": "circle"}, "mode": "markers", "name": "name=James Allan", "showlegend": true, "type": "scatter", "x": [7.5], "xaxis": "x", "y": [47], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=James P. Callan<br>Rank=%{x}<br>count=%{marker.size}", "legendgroup": "name=James P. Callan", "marker": {"color": "#B6E880", "size": [47], "sizemode": "area", "sizeref": 0.028055555555555556, "symbol": "circle"}, "mode": "markers", "name": "name=James P. Callan", "showlegend": true, "type": "scatter", "x": [7.5], "xaxis": "x", "y": [47], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=Craig MacDonald<br>Rank=%{x}<br>count=%{marker.size}", "legendgroup": "name=Craig MacDonald", "marker": {"color": "#FF97FF", "size": [45], "sizemode": "area", "sizeref": 0.028055555555555556, "symbol": "circle"}, "mode": "markers", "name": "name=Craig MacDonald", "showlegend": true, "type": "scatter", "x": [9.0], "xaxis": "x", "y": [45], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=Oren Kurland<br>Rank=%{x}<br>count=%{marker.size}", "legendgroup": "name=Oren Kurland", "marker": {"color": "#FECB52", "size": [40], "sizemode": "area", "sizeref": 0.028055555555555556, "symbol": "circle"}, "mode": "markers", "name": "name=Oren ...

# %%
#SIGIR refereneces per year
import pandas as pd
import numpy as np
ref=pd.read_csv("Reference_information.csv")
#df1 = ref.replace(np.nan, '', regex=True)
#df1.loc[df1['venue'].str.contains('SIGIR',na=False), 'venue'] = 'SIGIR'
#df2 = df1.loc[df1['venue'] == 'SIGIR']
refer_per_year = pd.DataFrame(ref['Reference _paper_year'].value_counts()).reset_index()
refer_per_year.columns = ['Year', 'Refereneces_Per_year']
sortref_by_year = refer_per_year.sort_values('Year')
sortref_by_year.to_csv("total references per year.csv")

# %%
#SIGIR Citations per year
import numpy as np
cit=pd.read_csv("Citation_Information_final.csv")
#cit1 = cit.replace(np.nan, '', regex=True)
#cit1.loc[cit1['venue'].str.contains('SIGIR',na=False), 'venue'] = 'SIGIR'
#cit2 = cit1.loc[cit1['venue'] == 'SIGIR']
cit_per_year = pd.DataFrame(cit['year'].value_counts()).reset_index()
cit_per_year.columns = ['Year', 'Citations_Per_Year']
sortcit_by_year = cit_per_year.sort_values('Year')
sortcit_by_year.to_csv("total citation per year.csv")

# %%
import os

if not os.path.exists("images"):
    os.mkdir("images")

# %%
#Comparision of citations and Refereneces each year
import plotly.graph_objects as go

fig = go.Figure(data=[
    go.Bar(name='Referencesperyear', x=sortref_by_year['Year'], y=sortref_by_year['Refereneces_Per_year']),
    go.Bar(name='citationsperyear', x=sortcit_by_year['Year'], y=sortcit_by_year['Citations_Per_Year'])
])
# Change the bar mode
fig.update_layout(barmode='group')
fig.update_layout(legend=dict(
    yanchor="top",
    y=0.99,
    xanchor="left",
    x=0.01
))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9aa1d402-0895-454c-8d40-d563e9c84f87" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9aa1d402-0895-454c-8d40-d563e9c84f87")) {
#                     Plotly.newPlot(
#                         '9aa1d402-0895-454c-8d40-d563e9c84f87',
#                         [{"name": "Referencesperyear", "type": "bar", "x": [1979.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1987.0, 1988.0, 1989.0, 1992.0, 1993.0, 1995.0, 1996.0, 1998.0, 1999.0, 2000.0, 2001.0, 2003.0, 2005.0, 2007.0, 2008.0, 2009.0], "y": [3, 3, 17, 20, 20, 8, 7, 4, 24, 7, 164, 37, 62, 157, 47, 5, 179, 2, 65, 677, 7, 469]}, {"name": "citationsperyear", "type": "bar", "x": [1973.0, 1980.0, 1981.0, 1982.0, 1983.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0], "y": [9, 3, 2, 2, 1, 11, 9, 31, 52, 100, 78, 62, 51, 100, 67, 120, 80, 244, 273, 263, 418, 532, 485, 654, 547, 513, 673, 565, 385, 450, 359, 323, 353, 334, 273, 243, 259, 248, 246]}],
#                         {"barmode": "group", "legend": {"x": 0.01, "xanchor": "left", "y": 0.99, "yanchor": "top"}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth":  ...

# %%
import pandas as pd

pub= pd.read_csv("Author_information.csv")
df1 = pub.groupby('name', as_index=False).agg({'Publicationcount':'sum'})
df2 =df1.sort_values('Publicationcount',ascending=False)
df3 = df2.head(40)
df3['Rank'] = df3['Publicationcount'].rank(method='dense', ascending=False)
df3.to_csv("Top 40 authors.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
import plotly.express as px
fig = px.scatter(df3, x="Publicationcount", y="Rank",
	         size="Publicationcount", color="name",
           text="name",
                 log_x=True, size_max=60)
fig.update_traces(textposition='middle center')

fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2f721fd0-12af-49c1-aca7-56a3bc03a2dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2f721fd0-12af-49c1-aca7-56a3bc03a2dc")) {
#                     Plotly.newPlot(
#                         '2f721fd0-12af-49c1-aca7-56a3bc03a2dc',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "name=%{text}<br>Publicationcount=%{marker.size}<br>Rank=%{y}", "legendgroup": "name=Maarten de Rijke", "marker": {"color": "#636efa", "size": [61352.0], "sizemode": "area", "sizeref": 17.04222222222222, "symbol": "circle"}, "mode": "markers+text", "name": "name=Maarten de Rijke", "showlegend": true, "text": ["Maarten de Rijke"], "textposition": "middle center", "type": "scatter", "x": [61352.0], "xaxis": "x", "y": [1.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=%{text}<br>Publicationcount=%{marker.size}<br>Rank=%{y}", "legendgroup": "name=W. Bruce Croft", "marker": {"color": "#EF553B", "size": [54864.0], "sizemode": "area", "sizeref": 17.04222222222222, "symbol": "circle"}, "mode": "markers+text", "name": "name=W. Bruce Croft", "showlegend": true, "text": ["W. Bruce Croft"], "textposition": "middle center", "type": "scatter", "x": [54864.0], "xaxis": "x", "y": [2.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=%{text}<br>Publicationcount=%{marker.size}<br>Rank=%{y}", "legendgroup": "name=Gang Chen", "marker": {"color": "#00cc96", "size": [31438.0], "sizemode": "area", "sizeref": 17.04222222222222, "symbol": "circle"}, "mode": "markers+text", "name": "name=Gang Chen", "showlegend": true, "text": ["Gang Chen"], "textposition": "middle center", "type": "scatter", "x": [31438.0], "xaxis": "x", "y": [3.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=%{text}<br>Publicationcount=%{marker.size}<br>Rank=%{y}", "legendgroup": "name=Wei Liu", "marker": {"color": "#ab63fa", "size": [29288.0], "sizemode": "area", "sizeref": 17.04222222222222, "symbol": "circle"}, "mode": "markers+text", "name": "name=Wei Liu", "showlegend": true, "text": ["Wei Liu"], "textposition": "middle center", "type": "scatter", "x": [29288.0], "xaxis": "x", "y": [4.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=%{text}<br>Publicationcount=%{marker.size}<br>Rank=%{y}", "legendgroup": "name=Zhigang Chen", "marker": {"color": "#FFA15A", "size": [27456.0], "sizemode": "area", "sizeref": 17.04222222222222, "symbol": "circle"}, "mode": "markers+text", "name": "name=Zhigang Chen", "showlegend": true, "text": ["Zhigang Chen"], "textposition": "middle center", "type": "scatter", "x": [27456.0], "xaxis": "x", "y": [5.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=%{text}<br>Publicationcount=%{marker.size}<br>Rank=%{y}", "legendgroup": "name=Yong Yu", "marker": {"color": "#19d3f3", "size": [26406.0], "sizemode": "area", "sizeref": 17.04222222222222, "symbol": "circle"}, "mode": "markers+text", "name": "name=Yong Yu", "showlegend": true, "text": ["Yong Yu"], "textposition": "middle center", "type": "scatter", "x": [26406.0], "xaxis": "x", "y": [6.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=%{text}<br>Publicationcount=%{marker.size}<br>Rank=%{y}", "legendgroup": "name=Tat-Seng Chua", "marker": {"color": "#FF6692", "size": [20361.0], "sizemode": "area", "sizeref": 17.04222222222222, "symbol": "circle"}, "mode": "markers+text", "name": "name=Tat-Seng Chua", "showlegend": true, "text": ["Tat-Seng Chua"], "textposition": "middle center", "type": "scatter", "x": [20361.0], "xaxis": "x", "y": [7.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=%{text}<br>Publicationcount=%{marker.size}<br>Rank=%{y}", "legendgroup": "name=ChengXiang Zhai", "marker": {"color": "#B6E880", "size": [19896.0], "sizemode": "area", "sizeref": 17.04222222222222, "symbol": "circle"}, "mode": "markers+text", "name": "name=ChengXiang Zhai", "showlegend": true, "text": ["ChengXiang Zhai"], "textposition": "middle center", "type": "scatter", "x": [19896.0], "xaxis": "x", "y": [8.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "name=%{text}<br>Publicationcount=%{marker.size}<br>Rank=%{y}", "legendgroup": "name=James Al ...

# %%
import pandas as pd

df = pd.read_csv("output.csv",usecols = ['article_title','article_year','total_citation'])
df
# Out:
#                                           article_title  ...  total_citation
# 0     The Importance of Interaction for Information ...  ...               1
# 1           Automatic Understanding of the Visual World  ...               0
# 2     A General Framework for Counterfactual Learnin...  ...               3
# 3     To Model or to Intervene: A Comparison of Coun...  ...               2
# 4         Domain Adaptation for Enterprise Email Search  ...               0
# ...                                                 ...  ...             ...
# 4557  Affective adaptive retrieval: study of emotion...  ...               1
# 4558  A study on performance volatility in informati...  ...               0
# 4559  Novelty detection across different source type...  ...               0
# 4560  Personalizing information retrieval using task...  ...               4
# 4561  Exploiting memory cues in personal lifelog ret...  ...               2
#
# [4562 rows x 3 columns]

# %%
#Keywords csv file
import pandas as pd 
df = pd.read_csv("output.csv",usecols = ['article_title','article_year','total_citation'])
df1=pd.read_csv("Article_information.csv",usecols = ['Title','Year','TotalCitationCount'])
df1.rename(columns = {'Title':'article_title'}, inplace = True) 
df1
# Out:
#                                           article_title  ...  TotalCitationCount
# 0     Introduction and perspectives for the 1971 ACM...  ...                   0
# 1     The function of semantics in automated languag...  ...                   6
# 2              How features resolve syntactic ambiguity  ...                   4
# 3     The converse natural language data management ...  ...                  10
# 4     CUE: a preprocessor system for restricted, nat...  ...                   4
# ...                                                 ...  ...                 ...
# 4428  Document Distance Metric Learning in an Intera...  ...                   0
# 4429                 Measuring Job Search Effectiveness  ...                   0
# 4430  Informing the Design of Conversational IR Syst...  ...                   1
# 4431           Evaluating Risk-Sensitive Text Retrieval  ...                   0
# 4432  Efficient and Effective Text-Annotation throug...  ...                   0
#
# [4433 rows x 3 columns]

# %%
mergedStuff = pd.merge(df, df1, on=['article_title'], how='inner')
mergedStuff.drop(['article_year', 'TotalCitationCount'], axis=1, inplace=True)
mergedStuff.to_csv("cit.csv")

# %%
import pandas as pd
df=pd.read_csv("cit.csv",thousands=',')
df['total_citation'] = pd.to_numeric(df['total_citation'])
df1=df[df.total_citation >= 100].groupby('Year')['total_citation'].count().reset_index()
df1.to_csv("citation_above_100.csv")

# %%
import plotly.graph_objects as go

colors = ['lightslategray',] * 27
colors[25] = 'crimson'

fig = go.Figure(data=[go.Bar(
    x=df1['Year'], y=df1['total_citation'],
    marker_color=colors # marker color can be a single color value or an iterable
)])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8789b2a7-a028-4b74-85e1-0b083255b942" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8789b2a7-a028-4b74-85e1-0b083255b942")) {
#                     Plotly.newPlot(
#                         '8789b2a7-a028-4b74-85e1-0b083255b942',
#                         [{"marker": {"color": ["lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "lightslategray", "crimson", "lightslategray"]}, "type": "bar", "x": [1985, 1991, 1992, 1993, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017], "y": [2, 2, 5, 8, 7, 7, 6, 15, 9, 6, 16, 12, 19, 17, 17, 22, 26, 25, 13, 8, 6, 12, 2, 2, 5, 1, 3]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
#top cited article each year
import pandas as pd
top_art=pd.read_csv("cit.csv",thousands=',')
top_art['total_citation'] = pd.to_numeric(top_art['total_citation'])
top_art
# Out:
#       Unnamed: 0  ... Unnamed: 4
# 0              0  ...        NaN
# 1              1  ...        NaN
# 2              2  ...        NaN
# 3              3  ...        NaN
# 4              4  ...        NaN
# ...          ...  ...        ...
# 4320        4320  ...        NaN
# 4321        4321  ...        NaN
# 4322        4322  ...        NaN
# 4323        4323  ...        NaN
# 4324        4324  ...        NaN
#
# [4325 rows x 5 columns]

# %%
res = top_art.groupby('Year')['total_citation'].max().reset_index()
res.columns = ['Year','total_citation']
res
# Out:
#     Year  total_citation
# 0   1971            11.0
# 1   1978             0.0
# 2   1979             0.0
# 3   1983            14.0
# 4   1985           158.0
# 5   1986            99.0
# 6   1987            23.0
# 7   1988            72.0
# 8   1989            93.0
# 9   1991           232.0
# 10  1992           251.0
# 11  1993           359.0
# 12  1995           557.0
# 13  1996           514.0
# 14  1997           366.0
# 15  1998          1164.0
# 16  1999          2656.0
# 17  2000           516.0
# 18  2001           371.0
# 19  2002           714.0
# 20  2003           778.0
# 21  2004           358.0
# 22  2005           678.0
# 23  2006           601.0
# 24  2007           386.0
# 25  2008           474.0
# 26  2009           408.0
# 27  2010           334.0
# 28  2011           532.0
# 29  2012           556.0
# 30  2013           341.0
# 31  2014           164.0
# 32  2015           332.0
# 33  2016           207.0
# 34  2017           156.0
# 35  2018            40.0
# 36  2019            16.0

# %%
df5 = top_art[top_art['total_citation'] == top_art.groupby('Year')['total_citation'].transform('max')]
df2 =df5.sort_values('Year',ascending=False)
df2
